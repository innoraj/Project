# %% [markdown]
# <a href="https://colab.research.google.com/github/innoraj/Project/blob/master/Classification_Algorithms_on_Dataset3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
start = time.time()
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
data = pd.read_csv('https://raw.githubusercontent.com/innoraj/Project/master/Dataset3.csv')
X = data.drop(['target'], axis=1)
y = data.target.copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=.8)
model = LogisticRegression()
model.fit(X_train, y_train)
end = time.time()
print("Execution time in Seconds ", end-start)
print("Accuracy ", model.score(X_test, y_test)*100)
LogisticRegression = model.score(X_test, y_test)*100
# Out:
# Execution time in Seconds  6.335424184799194
# Accuracy  77.04918032786885
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Execution time in Seconds  0.05224967002868652
# Accuracy  78.68852459016394
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
import time
start = time.time()
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
data = pd.read_csv('https://raw.githubusercontent.com/innoraj/Project/master/Dataset3.csv')
X = data.drop(['target'], axis=1)
y = data.target.copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=.8)
model = GaussianNB()
model.fit(X_train, y_train)
end = time.time()
print("Execution time in Seconds ", end-start)
print("Accuracy ", model.score(X_test, y_test)*100)
GaussianNB = model.score(X_test, y_test)*100
# Out:
# Execution time in Seconds  0.051970720291137695
# Accuracy  85.24590163934425
# Execution time in Seconds  0.04976320266723633
# Accuracy  88.52459016393442

# %%
import time
start = time.time()
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier
data = pd.read_csv('https://raw.githubusercontent.com/innoraj/Project/master/Dataset3.csv')
X = data.drop(['target'], axis=1)
y = data.target.copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=.8)
model = SGDClassifier(loss='modified_huber', shuffle=True, random_state=101)
model.fit(X_train, y_train)
end = time.time()
print("Execution time in Seconds ", end-start)
print("Accuracy ", model.score(X_test, y_test)*100)
SGDClassifier = model.score(X_test, y_test)*100
# Out:
# Execution time in Seconds  0.048737525939941406
# Accuracy  50.81967213114754
# Execution time in Seconds  0.04835820198059082
# Accuracy  60.65573770491803

# %%
import time
start = time.time()
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
data = pd.read_csv('https://raw.githubusercontent.com/innoraj/Project/master/Dataset3.csv')
X = data.drop(['target'], axis=1)
y = data.target.copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=.8)
model = KNeighborsClassifier(n_neighbors=15)
model.fit(X_train, y_train)
end = time.time()
print("Execution time in Seconds ", end-start)
print("Accuracy ", model.score(X_test, y_test)*100)
KNeighborsClassifier = model.score(X_test, y_test)*100
# Out:
# Execution time in Seconds  0.11690425872802734
# Accuracy  55.73770491803278
# Execution time in Seconds  0.04893183708190918
# Accuracy  63.934426229508205

# %%
import time
start = time.time()
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
data = pd.read_csv('https://raw.githubusercontent.com/innoraj/Project/master/Dataset3.csv')
X = data.drop(['target'], axis=1)
y = data.target.copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=.8)
model = DecisionTreeClassifier(max_depth=10, random_state=101, 
                               max_features = None, min_samples_leaf = 15)
model.fit(X_train, y_train)
end = time.time()
print("Execution time in Seconds ", end-start)
print("Accuracy ", model.score(X_test, y_test)*100)
DecisionTreeClassifier = model.score(X_test, y_test)*100
# Out:
# Execution time in Seconds  0.09162592887878418
# Accuracy  72.1311475409836
# Execution time in Seconds  0.0486752986907959
# Accuracy  78.68852459016394

# %%
import time
start = time.time()
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
data = pd.read_csv('https://raw.githubusercontent.com/innoraj/Project/master/Dataset3.csv')
X = data.drop(['target'], axis=1)
y = data.target.copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=.8)
model = RandomForestClassifier(n_estimators=70, oob_score=True, n_jobs=-1,
                            random_state=101, max_features = None, min_samples_leaf = 30)
model.fit(X_train, y_train)
end = time.time()
print("Execution time in Seconds ", end-start)
print("Accuracy ", model.score(X_test, y_test)*100)
RandomForestClassifier = model.score(X_test, y_test)*100
# Out:
# Execution time in Seconds  0.22319316864013672
# Accuracy  83.60655737704919
# Execution time in Seconds  0.296187162399292
# Accuracy  86.88524590163934

# %%
import time
start = time.time()
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
data = pd.read_csv('https://raw.githubusercontent.com/innoraj/Project/master/Dataset3.csv')
X = data.drop(['target'], axis=1)
y = data.target.copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=.8)
model = SVC(kernel="linear", C=0.025,random_state=101)
model.fit(X_train, y_train)
end = time.time()
print("Execution time in Seconds ", end-start)
print("Accuracy ", model.score(X_test, y_test)*100)
SVC = model.score(X_test, y_test)*100
# Out:
# Execution time in Seconds  0.0714712142944336
# Accuracy  86.88524590163934
# Execution time in Seconds  0.06705832481384277
# Accuracy  85.24590163934425

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
objects = ('Logistic Regression','GaussianNB','SGD Classifier','KNeighbors Classifier','DecisionTree Classifier','Random Forest Classifier', 'Support Vector Classifier')
y_pos = np.arange(len(objects))
performance = [LogisticRegression,GaussianNB,SGDClassifier,KNeighborsClassifier,DecisionTreeClassifier,RandomForestClassifier, SVC]
plt.bar(y_pos, performance, align='center', alpha=0.5,color='blue') 
plt.xticks(y_pos, objects,rotation=45)
plt.ylabel('Accuracy')
plt.title('Comparison of Model for Heart Attact Predection')
plt.show()
