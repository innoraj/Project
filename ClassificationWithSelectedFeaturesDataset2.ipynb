# %%
import pandas as pd
import numpy as np
np.random.seed(42)
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

data = pd.read_csv('https://raw.githubusercontent.com/innoraj/Project/master/Dataset2.csv')
data.dropna(inplace=True)

X = data.iloc[:,[10,1,9,4,11,7,8,5,0,12]]
y = data.iloc[:,-1]

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=.8)

modelLR = LogisticRegression()
modelLR.fit(X_train, y_train)

modelNB = GaussianNB()
modelNB.fit(X_train, y_train)

modelKN = KNeighborsClassifier(n_neighbors=5)
modelKN.fit(X_train, y_train)

modelDT = DecisionTreeClassifier(max_depth=10, random_state=42, max_features = None, min_samples_leaf = 15)
modelDT.fit(X_train, y_train)

modelSV = SVC(kernel="linear", C=0.025,random_state=42)
modelSV.fit(X_train, y_train)


print(" LogisticRegression ", modelLR.score(X_test, y_test)*100)
LogisticRegression = modelLR.score(X_test, y_test)*100
print(" GaussianNB ", modelNB.score(X_test, y_test)*100)
GaussianNB = modelNB.score(X_test, y_test)*100
print(" KNeighborsClassifier ", modelKN.score(X_test, y_test)*100)
KNeighborsClassifier = modelKN.score(X_test, y_test)*100
print(" DecisionTreeClassifier ", modelDT.score(X_test, y_test)*100)
DecisionTreeClassifier = modelDT.score(X_test, y_test)*100
print(" SupportVectorClassifier ", modelSV.score(X_test, y_test)*100)
SupportVectorClassifier = modelSV.score(X_test, y_test)*100
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#  LogisticRegression  83.60655737704919
#  GaussianNB  81.14754098360656
#  KNeighborsClassifier  82.24043715846994
#  DecisionTreeClassifier  81.28415300546447
#  SupportVectorClassifier  83.33333333333334

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
objects = ('Logistic Regression','GaussianNB','KNeighbors Classifier','DecisionTree Classifier', 'Support Vector Classifier')
y_pos = np.arange(len(objects))
performance = [LogisticRegression,GaussianNB,KNeighborsClassifier,DecisionTreeClassifier, SupportVectorClassifier]
plt.bar(y_pos, performance, align='center', alpha=0.5,color='blue') 
plt.xticks(y_pos, objects,rotation=45)
plt.ylabel('Accuracy')
plt.title('Comparison of Model for Heart Attact Prediction Dataset 2')
plt.show()
plt.savefig("Comparison of Model for Heart Attact Prediction Dataset 2.png")
files.download("Comparison of Model for Heart Attact Prediction Dataset 2.png")

# %%
results = pd.DataFrame({
    'Model': ['Logistic Regression','GaussianNB','KNeighbors Classifier','DecisionTree Classifier', 'Support Vector Classifier'],
    'Accuracy': [LogisticRegression,GaussianNB,KNeighborsClassifier,DecisionTreeClassifier,SupportVectorClassifier]})
result_df = results.sort_values(by='Accuracy', ascending=False)
result_df = result_df.set_index('Accuracy')
result_df.head(8)
# Out:
#                                Model
# Accuracy
# 83.606557        Logistic Regression
# 83.333333  Support Vector Classifier
# 82.240437      KNeighbors Classifier
# 81.284153    DecisionTree Classifier
# 81.147541                 GaussianNB
