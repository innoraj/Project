# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#Loadind the Data Set
data = pd.read_csv("C:/Users/Shanmugaraj/Dropbox/Project Files/Dataset1.csv")

# %%
# To See the dimension of the dataset
print(data.shape)
# Out:
# (70000, 13)

# %%
# See the column names
print(data.columns)
# Out:
# Index(['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
#To view the first 5 lines of the dataset
data.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
#To print information of all columns
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
# id             70000 non-null int64
# age            70000 non-null int64
# gender         70000 non-null int64
# height         70000 non-null int64
# weight         70000 non-null float64
# ap_hi          70000 non-null int64
# ap_lo          70000 non-null int64
# cholesterol    70000 non-null int64
# gluc           70000 non-null int64
# smoke          70000 non-null int64
# alco           70000 non-null int64
# active         70000 non-null int64
# cardio         70000 non-null int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB
# None

# %%
data['gender']= data.gender.astype(object)
data['cholesterol']= data.cholesterol.astype(object)
data['gluc']= data.gluc.astype(object)
data['smoke']= data.smoke.astype(object)
data['alco']= data.alco.astype(object)
data['active']= data.active.astype(object)
data['cardio']= data.cardio.astype(object)

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
# id             70000 non-null int64
# age            70000 non-null int64
# gender         70000 non-null object
# height         70000 non-null int64
# weight         70000 non-null float64
# ap_hi          70000 non-null int64
# ap_lo          70000 non-null int64
# cholesterol    70000 non-null object
# gluc           70000 non-null object
# smoke          70000 non-null object
# alco           70000 non-null object
# active         70000 non-null object
# cardio         70000 non-null object
# dtypes: float64(1), int64(5), object(7)
# memory usage: 6.9+ MB
# None

# %%
#To see whether we have any missing values
data.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %% [markdown]
# We can see that our dataset does not have any missing values

# %%
#To describe a numerical series
data.describe()
# Out:
#                  id           age        height        weight         ap_hi  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814    164.359229     74.205690    128.817286
# std    28851.302323   2467.251667      8.210126     14.395757    154.011419
# min        0.000000  10798.000000     55.000000     10.000000   -150.000000
# 25%    25006.750000  17664.000000    159.000000     65.000000    120.000000
# 50%    50001.500000  19703.000000    165.000000     72.000000    120.000000
# 75%    74889.250000  21327.000000    170.000000     82.000000    140.000000
# max    99999.000000  23713.000000    250.000000    200.000000  16020.000000
#
#               ap_lo
# count  70000.000000
# mean      96.630414
# std      188.472530
# min      -70.000000
# 25%       80.000000
# 50%       80.000000
# 75%       90.000000
# max    11000.000000

# %%
#to describe a categorical value
data.describe(include=['object'])
# Out:
#         gender  cholesterol   gluc  smoke   alco  active  cardio
# count    70000        70000  70000  70000  70000   70000   70000
# unique       2            3      3      2      2       2       2
# top          1            1      1      0      0       1       0
# freq     45530        52385  59479  63831  66236   56261   35021

# %%
#To describe a particular categorical value
data['cholesterol'].value_counts()
# Out:
# 1    52385
# 2     9549
# 3     8066
# Name: cholesterol, dtype: int64

# %%
data['gender'].value_counts()
# Out:
# 1    45530
# 2    24470
# Name: gender, dtype: int64

# %% [markdown]
# ## Visualization of Continuous variables

# %% [markdown]
# ## age

# %%
sns.distplot(data['age'])

# %%
sns.boxplot(x="cardio", y="height", data=data,
            whis="range", palette="vlag")

# %% [markdown]
# ## height

# %%
sns.distplot(data['height'])

# %%
sns.boxplot(x="cardio", y="height", data=data,
            whis="range", palette="vlag")

# %% [markdown]
# ## weight

# %%
sns.distplot(data['weight'])

# %%
sns.boxplot(x="cardio", y="weight", data=data,
            whis="range", palette="vlag")

# %% [markdown]
# ## ap_hi

# %%
sns.distplot(data['ap_hi'])

# %%
sns.boxplot(x="cardio", y="ap_hi", data=data,
            whis="range", palette="vlag")

# %% [markdown]
# ## ap_lo

# %%
sns.distplot(data['ap_lo'])

# %%
sns.boxplot(x="cardio", y="ap_lo", data=data,
            whis="range", palette="vlag")

# %%
# `pairplot()` 
# %config InlineBackend.figure_format = 'png' 
sns.pairplot(data[['age', 'height', 'weight', 
                 'ap_hi', 'ap_lo']]);

# %% [markdown]
# ## Analysis of Catagorical Variables

# %%
sns.countplot(x='gender', data=data)

# %%
sns.countplot(x='gender', hue= 'cardio', data=data)

# %% [markdown]
# ## cholesterol

# %%
sns.countplot(x='cholesterol', data=data)

# %%
sns.countplot(x='cholesterol', hue= 'cardio', data=data)

# %% [markdown]
# ## gluc

# %%
sns.countplot(x='gluc', data=data)

# %%
sns.countplot(x='gluc', hue= 'cardio', data=data)

# %% [markdown]
# ## smoke

# %%
sns.countplot(x='smoke', data=data)

# %%
sns.countplot(x='smoke', hue= 'cardio', data=data)

# %% [markdown]
# ## alco

# %%
sns.countplot(x='alco', data=data)

# %%
sns.countplot(x='alco', hue= 'cardio', data=data)

# %% [markdown]
# ## active

# %%
sns.countplot(x='active', data=data)

# %%
sns.countplot(x='active', hue= 'cardio', data=data)

# %%
import statsmodels.api as sm
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.metrics import confusion_matrix
import matplotlib.mlab as mlab
# %matplotlib inline

# %% [markdown]
# ## Extract the target variable

# %% [markdown]
# Create an X dataframe with the input features and an y series with the target (cardio)

# %%
y = data.cardio.copy() # copy “y” column values out

# %%
X = data.drop(['cardio'], axis=1) # then, drop y column

# %%
from sklearn.model_selection import train_test_split
  # 80 % go into the training test, 20% in the validation test
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, random_state=7)

# %%
X_train.shape, X_valid.shape, y_train.shape, y_valid.shape
# Out:
# ((56000, 12), (14000, 12), (56000,), (14000,))

# %% [markdown]
# ## Test logistic regression

# %% [markdown]
# Logistic regression is a type of regression analysis in statistics used for prediction of outcome of a categorical dependent variable from a set of predictor or independent variables. In logistic regression the dependent variable is always binary. Logistic regression is mainly used to for prediction and also calculating the probability of success.

# %%
#Logistic Regression

# %%
import time
start = time.time()
"the code you want to test stays here"

from sklearn.model_selection import train_test_split
from sklearn.model_selection import learning_curve, GridSearchCV
#from sklearn.grid_search import GridSearchCV
from sklearn.datasets import *
from sklearn.linear_model import LogisticRegression

data = pd.read_csv("C:/Users/shanmugaraj/Dropbox/Project Files/Dataset1.csv")
#data = pd.read_csv("C:/Users/shanmugaraj/Downloads/Dataset1.csv")
X = data.drop(['cardio'], axis=1)
y = data.cardio.copy()

tuned_parameters = [{'C': [10**-4, 10**-2, 10**0, 10**2, 10**4]}]
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=.9)


#Using GridSearchCV
model = GridSearchCV(LogisticRegression(), tuned_parameters, scoring = 'f1', cv=5)
model.fit(X_train, y_train)

print(model.best_estimator_)
print(model.score(X_test, y_test))

end = time.time()
print("Execution time in Seconds ")
print(end - start)
# Out:
# C:\Users\Shanmugaraj\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# C:\Users\Shanmugaraj\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Shanmugaraj\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Shanmugaraj\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
# Decision Tree Classifier
start = time.time()
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
dtc = DecisionTreeClassifier(random_state=0)

dtc.fit(X_train, y_train)

y_pred_class = dtc.predict(X_test)

# %%
from sklearn import metrics
# Accuracy
metrics.accuracy_score(y_test, y_pred_class)

end = time.time()
print("Execution time in Seconds ")
print(end - start)
# Out:
# 0.6355714285714286

# %%
#Adaboost classifier

# %%
start = time.time()
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score

abc = AdaBoostClassifier()

abc.fit(X_train, y_train)

y_pred = abc.predict(X_test)

accuracy_score(y_pred, y_test)
end = time.time()
print("Execution time in Seconds ")
print(end - start)
# Out:
# 0.727

# %%
# Support Vector Machine

# %%
start = time.time()
from sklearn.svm import SVC

# %%
svm = SVC(kernel='linear')

svm.fit(X_train, y_train)

y_pred = svm.predict(X_test)

# %%
# Accuracy calculation
from sklearn.metrics import accuracy_score
acc = accuracy_score(y_pred, y_test)
acc
end = time.time()
print("Execution time in Seconds ")
print(end - start)
# Out:
# 0.7111428571428572
